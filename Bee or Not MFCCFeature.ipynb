# %% [markdown]
# ## Introduction
# Greetings from the Kaggle bot! This is an automatically-generated kernel with starter code demonstrating how to read in the data and begin exploring. If you're inspired to dig deeper, click the blue "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first import libraries and define functions for plotting the data using `matplotlib`. Depending on the data, not all plots will be made. (Hey, I'm just a simple kerneling bot, not a Kaggle Competitions Grandmaster!)

# %%
pip uninstall protobuf

# %%
pip install --no-binary protobuf protobuf

# %%
pip uninstall tensorflow

# %%
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import librosa, librosa.display
import os
import glob
import cv2
from sklearn.model_selection import train_test_split

# importing all necessary libraries to run the code
import re,string
import numpy as np
import pandas as pd

import numpy as np # linear algebra
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import librosa, librosa.display
import sklearn

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
plt.figure(figsize=(3, 2))
print("NoBee")
x, fs = librosa.load("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\nobee\\CF003 - Active - Day - (214)-7-0.wav")
plt.rcParams['figure.figsize'] = (3,2) 
S = librosa.feature.melspectrogram(y=x, sr=fs, n_mels=128,fmax=8000)
mfccs=librosa.feature.mfcc(S=librosa.power_to_db(S))
print(mfccs.shape)
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)
librosa.display.specshow(mfccs, sr=fs)
plt.xlabel("Time (s)")
plt.ylabel("MFCC Coefficients ")
plt.tight_layout(pad=0)
plt.savefig('MFCCNoBee.pdf', bbox_inches='tight')

plt.figure(figsize=(3, 2))
import matplotlib.pyplot as plt
print("Bee")
x, fs = librosa.load("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\bee\\CF003 - Active - Day - (214)-0-0.wav")
plt.rcParams['figure.figsize'] = (3,2) 
S = librosa.feature.melspectrogram(y=x, sr=fs, n_mels=128,fmax=8000)
mfccs=librosa.feature.mfcc(S=librosa.power_to_db(S))
print(mfccs.shape)
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)
librosa.display.specshow(mfccs, sr=fs)
plt.xlabel("Time (s)")
plt.ylabel("MFCC Coefficients ")
plt.tight_layout(pad=0)
plt.savefig('MFCCBee.pdf', bbox_inches='tight')

plt.figure(figsize=(3, 2))
import matplotlib.pyplot as plt
print("NoQueen")
x, fs = librosa.load("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\noqueen\\CF001 - Missing Queen - Day --0-0.wav")
plt.rcParams['figure.figsize'] = (3,2) 
S = librosa.feature.melspectrogram(y=x, sr=fs, n_mels=128,fmax=8000)
mfccs=librosa.feature.mfcc(S=librosa.power_to_db(S))
print(mfccs.shape)
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)
librosa.display.specshow(mfccs, sr=fs)
plt.xlabel("Time (s)")
plt.ylabel("MFCC Coefficients ")
plt.tight_layout(pad=0)
plt.savefig('MFCCNoQueen.pdf', bbox_inches='tight')
# Out:
# NoBee
# (20, 87)
# Bee
# (20, 87)
# NoQueen
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:194: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:211: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:194: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:211: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:194: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:211: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "
# (20, 87)

# %%
from scipy.io.wavfile import read
a = read("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\noqueen\\CF001 - Missing Queen - Day --0-0.wav")
mf=np.array(a[1],dtype=float)
b = mf.ravel()
b.shape
# Out:
# (176400,)

# %%
mf
# Out:
# array([[-3.300e+01, -2.000e+00],
#        [-3.300e+01, -2.000e+00],
#        [-4.100e+01, -3.000e+00],
#        ...,
#        [ 4.150e+03,  3.000e+00],
#        [ 4.090e+03,  5.000e+00],
#        [ 4.031e+03,  5.000e+00]])

# %%
import matplotlib.pyplot as plt
print("NoQueen")
x, fs = librosa.load("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\noqueen\\CF001 - Missing Queen - Day --0-0.wav")

plt.rcParams['figure.figsize'] = (3,2) 
S = librosa.feature.melspectrogram(y=x, sr=fs, n_mels=128,fmax=8000)
mfccs=librosa.feature.mfcc(S=librosa.power_to_db(S))

print(mfccs.shape)
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)
librosa.display.specshow(mfccs, sr=fs, x_axis='time')

plt.tight_layout(pad=0)
plt.savefig('MFCCNoQueen.pdf', bbox_inches='tight')
# Out:
# NoQueen
# (20, 87)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:194: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:211: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "

# %%
from sklearn.utils import shuffle
def get_images(directory):
    Feature = []
    Labels = [] 
    
    for labels in os.listdir(directory): 
        
        for image_file in os.listdir(directory+labels): 
            from scipy.io.wavfile import read
            a = read(directory+labels+r'/'+image_file)
            #mf=np.array(a[1],dtype=float)
            #x, fs = librosa.load(directory+labels+r'/'+image_file) 
            #S = librosa.feature.melspectrogram(y=x, sr=fs, n_mels=128,fmax=8000)
            #mf=librosa.feature.mfcc(S=librosa.power_to_db(S))
            mf=np.compress((a > 0)[1], a, axis=0)
            Feature.append(mf)
            Labels.append(labels)
    
    return shuffle(Feature,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

# %%
#Train data
Feature, Labels = get_images("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\") #Extract the training images from the folders.

Feature = np.array(Feature) #converting the list of images to numpy array.
Labels = np.array(Labels)

# %%
Feature
# Out:
# array([[ 0.01191359,  0.01820804,  0.01651604, ...,  0.00867292,
#          0.01122697,  0.01013726],
#        [-0.00137123, -0.00122711, -0.00120807, ...,  0.00019557,
#          0.00059108,  0.0010873 ],
#        [ 0.0003134 ,  0.00246066,  0.00103305, ..., -0.01166967,
#         -0.00683667, -0.00811486],
#        ...,
#        [-0.00035163,  0.00069712,  0.00112799, ...,  0.00556887,
#          0.00445647,  0.0043231 ],
#        [-0.01478308, -0.01967345, -0.01501582, ...,  0.00941017,
#          0.00883215,  0.00620611],
#        [-0.01993437, -0.02615351, -0.02061015, ..., -0.00420357,
#         -0.00466541, -0.00649495]], dtype=float32)

# %%
import numpy as np # linear algebra

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import glob
import cv2
import tensorflow as tf
from keras import layers
from keras.layers import Dropout , Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from sklearn.model_selection import train_test_split
import keras.backend as K
from sklearn.utils import shuffle
# importing all necessary libraries to run the code
import re,string
import numpy as np
import pandas as pd
import keras_metrics
import tensorflow.keras
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation,Embedding
# using the variable sw to hold all stopwords that are in English
sw = stopwords.words('english')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-5d6d1ad4ed71> in <module>
#       9 import glob
#      10 import cv2
# ---> 11 import tensorflow as tf
#      12 from keras import layers
#      13 from keras.layers import Dropout , Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\__init__.py in <module>
#      44
#      45 # Bring in subpackages.
# ---> 46 from tensorflow.python import data
#      47 from tensorflow.python import distribute
#      48 from tensorflow.python import keras
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\__init__.py in <module>
#      23
#      24 # pylint: disable=unused-import
# ---> 25 from tensorflow.python.data import experimental
#      26 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      27 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\experimental\__init__.py in <module>
#      97
#      98 # pylint: disable=unused-import
# ---> 99 from tensorflow.python.data.experimental import service
#     100 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#     101 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\experimental\service\__init__.py in <module>
#     138 from __future__ import print_function
#     139
# --> 140 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     141 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     142 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py in <module>
#      23
#      24 from tensorflow.python import tf2
# ---> 25 from tensorflow.python.data.experimental.ops import compression_ops
#      26 from tensorflow.python.data.experimental.ops.distribute_options import AutoShardPolicy
#      27 from tensorflow.python.data.experimental.ops.distribute_options import ExternalStatePolicy
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py in <module>
#      18 from __future__ import print_function
#      19
# ---> 20 from tensorflow.python.data.util import structure
#      21 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      22
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\util\structure.py in <module>
#      24 import wrapt
#      25
# ---> 26 from tensorflow.python.data.util import nest
#      27 from tensorflow.python.framework import composite_tensor
#      28 from tensorflow.python.framework import ops
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\util\nest.py in <module>
#      38 import six as _six
#      39
# ---> 40 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      41 from tensorflow.python.util import _pywrap_utils
#      42 from tensorflow.python.util import nest
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\sparse_tensor.py in <module>
#      26 from tensorflow.python import tf2
#      27 from tensorflow.python.framework import composite_tensor
# ---> 28 from tensorflow.python.framework import constant_op
#      29 from tensorflow.python.framework import dtypes
#      30 from tensorflow.python.framework import ops
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\constant_op.py in <module>
#      27 from tensorflow.core.framework import types_pb2
#      28 from tensorflow.python.eager import context
# ---> 29 from tensorflow.python.eager import execute
#      30 from tensorflow.python.framework import dtypes
#      31 from tensorflow.python.framework import op_callbacks
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\execute.py in <module>
#      26 from tensorflow.python.eager import core
#      27 from tensorflow.python.framework import dtypes
# ---> 28 from tensorflow.python.framework import ops
#      29 from tensorflow.python.framework import tensor_shape
#      30 from tensorflow.python.util import compat
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\ops.py in <module>
#      52 from tensorflow.python.framework import c_api_util
#      53 from tensorflow.python.framework import composite_tensor
# ---> 54 from tensorflow.python.framework import cpp_shape_inference_pb2
#      55 from tensorflow.python.framework import device as pydev
#      56 from tensorflow.python.framework import dtypes
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\cpp_shape_inference_pb2.py in <module>
#      25   serialized_pb=_b('\n5tensorflow/python/framework/cpp_shape_inference.proto\x12\ntensorflow\x1a%tensorflow/core/framework/types.proto\x1a,tensorflow/core/framework/tensor_shape.proto\"\xa5\x03\n\x17\x43ppShapeInferenceResult\x12+\n\x05shape\x18\x01 \x01(\x0b\x32\x1c.tensorflow.TensorShapeProto\x12\x43\n\x0bhandle_data\x18\x04 \x01(\x0b\x32..tensorflow.CppShapeInferenceResult.HandleData\x1a\x9d\x01\n\x12HandleShapeAndType\x12+\n\x05shape\x18\x01 \x01(\x0b\x32\x1c.tensorflow.TensorShapeProto\x12#\n\x05\x64type\x18\x02 \x01(\x0e\x32\x14.tensorflow.DataType\x12\x35\n\x10specialized_type\x18\x03 \x01(\x0e\x32\x1b.tensorflow.SpecializedType\x1al\n\nHandleData\x12\x0e\n\x06is_set\x18\x01 \x01(\x08\x12N\n\x0eshape_and_type\x18\x02 \x03(\x0b\x32\x36.tensorflow.CppShapeInferenceResult.HandleShapeAndTypeJ\x04\x08\x02\x10\x03J\x04\x08\x03\x10\x04\"e\n\x1d\x43ppShapeInferenceInputsNeeded\x12\x1c\n\x14input_tensors_needed\x18\x01 \x03(\x05\x12&\n\x1einput_tensors_as_shapes_needed\x18\x02 \x03(\x05\x42\x61Z\\github.com/tensorflow/tensorflow/tensorflow/go/python/framework/cpp_shape_inference_go_proto\xf8\x01\x01\x62\x06proto3')
#      26   ,
# ---> 27   dependencies=[tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,])
#      28
#      29
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\descriptor.py in __new__(cls, name, package, options, serialized_options, serialized_pb, dependencies, public_dependencies, syntax, pool, create_key)
#     980           raise RuntimeError('Please link in cpp generated lib for %s' % (name))
#     981       elif serialized_pb:
# --> 982         return _message.default_pool.AddSerializedFile(serialized_pb)
#     983       else:
#     984         return super(FileDescriptor, cls).__new__(cls)
#
# TypeError: Couldn't build proto file into descriptor pool!
# Invalid proto descriptor for file "tensorflow/python/framework/cpp_shape_inference.proto":
#   tensorflow.CppShapeInferenceResult.HandleShapeAndType.specialized_type: ".tensorflow.SpecializedType" is not defined.

# %%
pip install protobuf

# %%
pip uninstall protobuf

# %%
pip install --no-binary protobuf protobuf

# %%
pip install --no-binary protobuf protobuf

# %%
pip install tensorflow

# %%
def get_images(directory):
    MFCCFeature = []
    Labels = [] 
    
    for labels in os.listdir(directory): 
        
        for image_file in os.listdir(directory+labels): 
            #from scipy.io.wavfile import read
            #a = read(directory+labels+r'/'+image_file)
            #mf=numpy.array(a[1],dtype=float)
            x, fs = librosa.load(directory+labels+r'/'+image_file) 
            #S = librosa.feature.melspectrogram(y=x, sr=fs, n_mels=128,fmax=8000)
            #mf=librosa.feature.mfcc(S=librosa.power_to_db(S))
            MFCCFeature.append(x)
            Labels.append(labels)
    
    return shuffle(MFCCFeature,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

# %%
#Train data
MFCCFeature, Labels = get_images("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\") #Extract the training images from the folders.

MFCCFeature = np.array(MFCCFeature) #converting the list of images to numpy array.
Labels = np.array(Labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ef19a8c903eb> in <module>
#       1 #Train data
# ----> 2 MFCCFeature, Labels = get_images("C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\nuhive_processed\\") #Extract the training images from the folders.
#       3
#       4 MFCCFeature = np.array(MFCCFeature) #converting the list of images to numpy array.
#       5 Labels = np.array(Labels)
#
# <ipython-input-19-76b1b62338e4> in get_images(directory)
#       9             #a = read(directory+labels+r'/'+image_file)
#      10             #mf=numpy.array(a[1],dtype=float)
# ---> 11             x, fs = librosa.load(directory+labels+r'/'+image_file)
#      12             #S = librosa.feature.melspectrogram(y=x, sr=fs, n_mels=128,fmax=8000)
#      13             #mf=librosa.feature.mfcc(S=librosa.power_to_db(S))
#
# NameError: name 'librosa' is not defined

# %%
from collections import Counter
Counter(Labels)
# Out:
# Counter({'bee': 5473, 'noqueen': 4861, 'nobee': 3458})

# %%
MFCCFeature.shape
# Out:
# (13792, 20, 87)

# %% [raw]
# np.save('C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\MFCCFeature.npy', MFCCFeature)
# np.save('C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\MFCCFeaturelabels.npy', Labels)

# %% [raw]
# MFCCFeature = np.load('C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\MFCCFeature.npy')
# Labels = np.load('C:\\Users\\Sohail_Comp\\Downloads\\Bee or not bee\\MFCCFeaturelabels.npy')

# %%
n_samples = len(MFCCFeature)
data_MFCCFeature = MFCCFeature.reshape(n_samples, -1)

# %%
data_MFCCFeature.shape
# Out:
# (13792, 1740)

# %%
# Splitting dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_MFCCFeature, Labels, test_size=0.20, shuffle=True)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier() 
knn.fit(X_train,y_train)
yhat_classes = knn.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.87      0.91      0.89      1091
#        nobee       0.76      0.52      0.62       706
#      noqueen       0.80      0.95      0.87       962
#
#     accuracy                           0.83      2759
#    macro avg       0.81      0.79      0.79      2759
# weighted avg       0.82      0.83      0.82      2759

# %%
from sklearn.linear_model import LogisticRegression
a=LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
#fit to the trainin data
a.fit(X_train,y_train)
yhat_classes = a.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.75      0.78      0.76      1098
#        nobee       0.51      0.41      0.45       655
#      noqueen       0.74      0.81      0.77      1006
#
#     accuracy                           0.70      2759
#    macro avg       0.67      0.67      0.66      2759
# weighted avg       0.69      0.70      0.69      2759
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
from sklearn.svm import SVC
print("SVC")
svm = SVC(kernel='poly', C=4.0, random_state=500)
svm.fit(X_train,y_train)
y_pred=svm.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# SVC
# 0.7147517216382747
#               precision    recall  f1-score   support
#
#          bee       0.79      0.76      0.78      1129
#        nobee       0.52      0.36      0.43       677
#      noqueen       0.72      0.92      0.81       953
#
#     accuracy                           0.71      2759
#    macro avg       0.68      0.68      0.67      2759
# weighted avg       0.70      0.71      0.70      2759

# %%
from sklearn.ensemble import RandomForestClassifier
print("RF")
rfc = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)  
rfc.fit(X_train, y_train)
# calculate accuracy of class predictions
y_pred = rfc.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# RF
#               precision    recall  f1-score   support
#
#          bee       0.85      0.93      0.89      1098
#        nobee       0.75      0.44      0.55       655
#      noqueen       0.82      0.96      0.88      1006
#
#     accuracy                           0.82      2759
#    macro avg       0.80      0.77      0.77      2759
# weighted avg       0.81      0.82      0.81      2759

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

pca = PCA(n_components=50)
pca_result = pca.fit_transform(data_MFCCFeature)
# Splitting dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_MFCCFeature, Labels, test_size=0.20, shuffle=True)

# %%
f = pd.DataFrame(data_MFCCFeature)
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt


# %matplotlib inline

df1=f

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# For reproducability of the results
np.random.seed(42)
rndperm = np.random.permutation(df1.shape[0])
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df1.values)
df1['pca-one'] = pca_result[:,0]
df1['pca-two'] = pca_result[:,1] 

plt.figure(figsize=(6,4),dpi=400)
plt.rcParams.update({'font.size': 14})
plt.ylabel('PCA-one', fontsize=14)
plt.xlabel('PCA-two', fontsize=14)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue=Labels,
    data=df1.loc[rndperm,:],
    legend="full",
    alpha=1.0
)
plt.tight_layout(pad=0)
plt.savefig('MFCCPCA.pdf', bbox_inches='tight')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier() 
knn.fit(X_train,y_train)
yhat_classes = knn.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.86      0.90      0.88      1109
#        nobee       0.75      0.51      0.61       688
#      noqueen       0.81      0.95      0.88       962
#
#     accuracy                           0.82      2759
#    macro avg       0.81      0.79      0.79      2759
# weighted avg       0.82      0.82      0.81      2759

# %%
from sklearn.linear_model import LogisticRegression
a=LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
#fit to the trainin data
a.fit(X_train,y_train)
yhat_classes = a.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.75      0.79      0.77      1113
#        nobee       0.49      0.39      0.44       668
#      noqueen       0.73      0.80      0.76       978
#
#     accuracy                           0.70      2759
#    macro avg       0.66      0.66      0.66      2759
# weighted avg       0.68      0.70      0.69      2759
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
from sklearn.svm import SVC
print("SVC")
svm = SVC(kernel='poly', C=4.0, random_state=500)
svm.fit(X_train,y_train)
y_pred=svm.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# SVC
# 0.7259876766944545
#               precision    recall  f1-score   support
#
#          bee       0.79      0.79      0.79      1113
#        nobee       0.53      0.36      0.43       668
#      noqueen       0.74      0.91      0.81       978
#
#     accuracy                           0.73      2759
#    macro avg       0.69      0.68      0.68      2759
# weighted avg       0.71      0.73      0.71      2759

# %%
from sklearn.ensemble import RandomForestClassifier
print("RF")
rfc = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)  
rfc.fit(X_train, y_train)
# calculate accuracy of class predictions
y_pred = rfc.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# RF
#               precision    recall  f1-score   support
#
#          bee       0.85      0.94      0.89      1113
#        nobee       0.77      0.42      0.54       668
#      noqueen       0.80      0.96      0.88       978
#
#     accuracy                           0.82      2759
#    macro avg       0.81      0.77      0.77      2759
# weighted avg       0.82      0.82      0.80      2759

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=50)
# prepare transform on dataset
svd.fit(data_MFCCFeature)
# apply transform to dataset
transformed = svd.transform(data_MFCCFeature)
# Splitting dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(transformed, Labels, test_size=0.20, shuffle=True)

# %%
f = pd.DataFrame(data_MFCCFeature)
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt


# %matplotlib inline

df1=f

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# For reproducability of the results
np.random.seed(42)
rndperm = np.random.permutation(df1.shape[0])
svd = TruncatedSVD(n_components=2)
# prepare transform on dataset
svd.fit(df1)
# apply transform to dataset
pca_result = svd.transform(df1)

df1['pca-one'] = pca_result[:,0]
df1['pca-two'] = pca_result[:,1] 

plt.figure(figsize=(6,4),dpi=400)
plt.rcParams.update({'font.size': 14})
plt.ylabel('SVD-one', fontsize=14)
plt.xlabel('SVD-two', fontsize=14)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue=Labels,
    data=df1.loc[rndperm,:],
    legend="full",
    alpha=1.0
)
plt.tight_layout(pad=0)
plt.savefig('MFCCTruncatedSVDs.pdf', bbox_inches='tight')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier() 
knn.fit(X_train,y_train)
yhat_classes = knn.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.88      0.91      0.90      1071
#        nobee       0.76      0.54      0.63       717
#      noqueen       0.82      0.96      0.88       971
#
#     accuracy                           0.83      2759
#    macro avg       0.82      0.80      0.80      2759
# weighted avg       0.83      0.83      0.82      2759

# %%
from sklearn.linear_model import LogisticRegression
a=LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
#fit to the trainin data
a.fit(X_train,y_train)
yhat_classes = a.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.72      0.76      0.74      1110
#        nobee       0.52      0.39      0.44       698
#      noqueen       0.69      0.76      0.72       951
#
#     accuracy                           0.67      2759
#    macro avg       0.64      0.64      0.64      2759
# weighted avg       0.66      0.67      0.66      2759
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
from sklearn.svm import SVC
print("SVC")
svm = SVC(kernel='poly', C=4.0, random_state=500)
svm.fit(X_train,y_train)
y_pred=svm.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# SVC
# 0.7198260239217108
#               precision    recall  f1-score   support
#
#          bee       0.79      0.77      0.78      1110
#        nobee       0.56      0.37      0.45       698
#      noqueen       0.72      0.92      0.81       951
#
#     accuracy                           0.72      2759
#    macro avg       0.69      0.69      0.68      2759
# weighted avg       0.71      0.72      0.70      2759

# %%
from sklearn.ensemble import RandomForestClassifier
print("RF")
rfc = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)  
rfc.fit(X_train, y_train)
# calculate accuracy of class predictions
y_pred = rfc.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# RF
#               precision    recall  f1-score   support
#
#          bee       0.86      0.94      0.90      1110
#        nobee       0.78      0.48      0.60       698
#      noqueen       0.82      0.96      0.89       951
#
#     accuracy                           0.83      2759
#    macro avg       0.82      0.80      0.79      2759
# weighted avg       0.83      0.83      0.82      2759

# %%
data_MFCCFeature1=abs(data_MFCCFeature)

# %%
# Load libraries
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
  
# Convert to categorical data by converting data to integers
X = data_MFCCFeature1.astype(int)
  
# Two features with highest chi-squared statistics are selected
chi2_features = SelectKBest(chi2, k = 500)
X_kbest_features = chi2_features.fit_transform(X, Labels)
  
# Splitting dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_kbest_features, Labels, test_size=0.20, shuffle=True)

# %%
f = pd.DataFrame(data_MFCCFeature1)
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt


# %matplotlib inline

df1=f

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# For reproducability of the results
np.random.seed(42)
rndperm = np.random.permutation(df1.shape[0])

chi2_features = SelectKBest(chi2, k = 2)
pca_result = chi2_features.fit_transform(df1, Labels)

df1['pca-one'] = pca_result[:,0]
df1['pca-two'] = pca_result[:,1] 

plt.figure(figsize=(6,4),dpi=400)
plt.rcParams.update({'font.size': 14})
plt.ylabel('Chi2-one', fontsize=14)
plt.xlabel('Chi2-two', fontsize=14)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue=Labels,
    data=df1.loc[rndperm,:],
    legend="full",
    alpha=1.0
)
plt.tight_layout(pad=0)
plt.savefig('MFCCChi2.pdf', bbox_inches='tight')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier() 
knn.fit(X_train,y_train)
yhat_classes = knn.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.82      0.85      0.83      1074
#        nobee       0.66      0.41      0.51       687
#      noqueen       0.75      0.92      0.83       998
#
#     accuracy                           0.77      2759
#    macro avg       0.75      0.73      0.72      2759
# weighted avg       0.76      0.77      0.75      2759

# %%
from sklearn.linear_model import LogisticRegression
a=LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
#fit to the trainin data
a.fit(X_train,y_train)
yhat_classes = a.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.74      0.78      0.76      1120
#        nobee       0.50      0.34      0.41       681
#      noqueen       0.69      0.81      0.75       958
#
#     accuracy                           0.68      2759
#    macro avg       0.65      0.64      0.64      2759
# weighted avg       0.67      0.68      0.67      2759
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
from sklearn.svm import SVC
print("SVC")
svm = SVC(kernel='poly', C=4.0, random_state=500)
svm.fit(X_train,y_train)
y_pred=svm.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# SVC
# 0.6908300108735049
#               precision    recall  f1-score   support
#
#          bee       0.77      0.73      0.75      1120
#        nobee       0.56      0.32      0.41       681
#      noqueen       0.66      0.91      0.77       958
#
#     accuracy                           0.69      2759
#    macro avg       0.67      0.65      0.64      2759
# weighted avg       0.68      0.69      0.67      2759

# %%
from sklearn.ensemble import RandomForestClassifier
print("RF")
rfc = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)  
rfc.fit(X_train, y_train)
# calculate accuracy of class predictions
y_pred = rfc.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# RF
#               precision    recall  f1-score   support
#
#          bee       0.83      0.94      0.88      1120
#        nobee       0.78      0.44      0.56       681
#      noqueen       0.81      0.93      0.87       958
#
#     accuracy                           0.81      2759
#    macro avg       0.81      0.77      0.77      2759
# weighted avg       0.81      0.81      0.80      2759

# %% [markdown]
# # Hybrid

# %%
chi=pd.DataFrame(X_kbest_features)
svd=pd.DataFrame(transformed)
pca=pd.DataFrame(pca_result)
mfcc=pd.DataFrame(data_MFCCFeature)
result = pd.concat([chi, svd,pca,mfcc], axis=1).reindex(chi.index)

# %%
# Splitting dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(result, Labels, test_size=0.20, shuffle=True)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier() 
knn.fit(X_train,y_train)
yhat_classes = knn.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.87      0.92      0.89      1089
#        nobee       0.75      0.50      0.60       690
#      noqueen       0.81      0.95      0.88       980
#
#     accuracy                           0.83      2759
#    macro avg       0.81      0.79      0.79      2759
# weighted avg       0.82      0.83      0.81      2759

# %%
from sklearn.linear_model import LogisticRegression
a=LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
#fit to the trainin data
a.fit(X_train,y_train)
yhat_classes = a.predict(X_test)
print(classification_report(y_test, yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#          bee       0.76      0.81      0.78      1089
#        nobee       0.49      0.33      0.40       690
#      noqueen       0.74      0.86      0.80       980
#
#     accuracy                           0.71      2759
#    macro avg       0.66      0.67      0.66      2759
# weighted avg       0.69      0.71      0.69      2759
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
from sklearn.svm import SVC
print("SVC")
svm = SVC(kernel='poly', C=4.0, random_state=500)
svm.fit(X_train,y_train)
y_pred=svm.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# SVC
# 0.7277999275099674
#               precision    recall  f1-score   support
#
#          bee       0.78      0.78      0.78      1089
#        nobee       0.56      0.35      0.43       690
#      noqueen       0.74      0.94      0.83       980
#
#     accuracy                           0.73      2759
#    macro avg       0.69      0.69      0.68      2759
# weighted avg       0.71      0.73      0.71      2759

# %%
from sklearn.ensemble import RandomForestClassifier
print("RF")
rfc = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)  
rfc.fit(X_train, y_train)
# calculate accuracy of class predictions
y_pred = rfc.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# RF
#               precision    recall  f1-score   support
#
#          bee       0.83      0.95      0.89      1089
#        nobee       0.78      0.42      0.55       690
#      noqueen       0.82      0.97      0.89       980
#
#     accuracy                           0.82      2759
#    macro avg       0.81      0.78      0.77      2759
# weighted avg       0.82      0.82      0.80      2759

# %%
X=data_MFCCFeature
y=Labels

from sklearn.model_selection import cross_val_score
clf =KNeighborsClassifier(n_neighbors=100) 
scores = cross_val_score(clf, X, y, cv=5)
print("KNN %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
scores = cross_val_score(clf, X, y, cv=5)
print("Lr %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =SVC(kernel='poly', C=2.0, random_state=500)
scores = cross_val_score(clf, X, y, cv=5)
print("svc %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)
scores = cross_val_score(clf, X, y, cv=5)
print("rf %0.2f +/- %0.2f" % (scores.mean(), scores.std()))
# Out:
# KNN 0.79 +/- 0.00
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Lr 0.70 +/- 0.01
# svc 0.71 +/- 0.01
# rf 0.82 +/- 0.01

# %%
X=transformed
y=Labels

from sklearn.model_selection import cross_val_score
clf =KNeighborsClassifier(n_neighbors=100) 
scores = cross_val_score(clf, X, y, cv=5)
print("KNN %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
scores = cross_val_score(clf, X, y, cv=5)
print("Lr %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =SVC(kernel='poly', C=2.0, random_state=500)
scores = cross_val_score(clf, X, y, cv=5)
print("svc %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)
scores = cross_val_score(clf, X, y, cv=5)
print("rf %0.2f +/- %0.2f" % (scores.mean(), scores.std()))
# Out:
# KNN 0.80 +/- 0.01
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Lr 0.67 +/- 0.01
# svc 0.70 +/- 0.01
# rf 0.83 +/- 0.01

# %%
X=pca_result
y=Labels

from sklearn.model_selection import cross_val_score
clf =KNeighborsClassifier(n_neighbors=100) 
scores = cross_val_score(clf, X, y, cv=5)
print("KNN %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
scores = cross_val_score(clf, X, y, cv=5)
print("Lr %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =SVC(kernel='poly', C=2.0, random_state=500)
scores = cross_val_score(clf, X, y, cv=5)
print("svc %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)
scores = cross_val_score(clf, X, y, cv=5)
print("rf %0.2f +/- %0.2f" % (scores.mean(), scores.std()))
# Out:
# KNN 0.80 +/- 0.00
# Lr 0.67 +/- 0.01
# svc 0.75 +/- 0.01
# rf 0.83 +/- 0.01

# %%
X=X_kbest_features
y=Labels

from sklearn.model_selection import cross_val_score
clf =KNeighborsClassifier(n_neighbors=100) 
scores = cross_val_score(clf, X, y, cv=5)
print("KNN %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
scores = cross_val_score(clf, X, y, cv=5)
print("Lr %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =SVC(kernel='poly', C=2.0, random_state=500)
scores = cross_val_score(clf, X, y, cv=5)
print("svc %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)
scores = cross_val_score(clf, X, y, cv=5)
print("rf %0.2f +/- %0.2f" % (scores.mean(), scores.std()))
# Out:
# KNN 0.75 +/- 0.00
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Lr 0.67 +/- 0.01
# svc 0.67 +/- 0.01
# rf 0.80 +/- 0.00

# %%
X=result
y=Labels

from sklearn.model_selection import cross_val_score
clf =KNeighborsClassifier(n_neighbors=100) 
scores = cross_val_score(clf, X, y, cv=5)
print("KNN %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =LogisticRegression(random_state=1000, solver='saga',multi_class='multinomial',C=5.0)
scores = cross_val_score(clf, X, y, cv=5)
print("Lr %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf =SVC(kernel='poly', C=2.0, random_state=500)
scores = cross_val_score(clf, X, y, cv=5)
print("svc %0.2f +/- %0.2f" % (scores.mean(), scores.std()))


from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(n_estimators=300, random_state=5, max_depth=200)
scores = cross_val_score(clf, X, y, cv=5)
print("rf %0.2f +/- %0.2f" % (scores.mean(), scores.std()))
# Out:
# KNN 0.79 +/- 0.00
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Lr 0.72 +/- 0.01
# svc 0.72 +/- 0.01
# rf 0.82 +/- 0.01

# %%
import numpy as np # linear algebra

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import glob
import cv2
import tensorflow as tf
from keras import layers
from keras.layers import Dropout , Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from sklearn.model_selection import train_test_split
import keras.backend as K
from sklearn.utils import shuffle
# importing all necessary libraries to run the code
import re,string
import numpy as np
import pandas as pd
import keras_metrics
import tensorflow.keras
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation,Embedding
# using the variable sw to hold all stopwords that are in English
sw = stopwords.words('english')

result1= abs(result)

Y = pd.get_dummies(Labels).values

X_train, X_valid, Y_train, Y_valid = train_test_split(result1,Y, test_size = 0.20, random_state =2)
batch_size=128

# %%
#Deep Learning Network Structure
model_conv = Sequential()
model_conv.add(Embedding(6000,100, input_length=result1.shape[1]))
model_conv.add(Dropout(0.2))
model_conv.add(LSTM(32))
model_conv.add(Dropout(0.2))
model_conv.add(Dense(3, activation='softmax'))
model_conv.compile(loss='categorical_crossentropy', optimizer='adam',   metrics=['accuracy','mae','mse',keras_metrics.precision(), keras_metrics.recall(),keras_metrics.f1_score()])
#Y = data.Reviewer_Score

pred=model_conv.fit(X_train, Y_train, batch_size =batch_size, epochs =100, verbose =2,validation_data=(X_valid,Y_valid))
pred
# Out:
# Epoch 1/100
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\keras\engine\base_layer.py:1307: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\keras\engine\base_layer.py:1307: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '
# 87/87 - 174s - loss: 1.0830 - accuracy: 0.3945 - mae: 0.4378 - mse: 0.2188 - precision: 0.0000e+00 - recall: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 1.0807 - val_accuracy: 0.3976 - val_mae: 0.4367 - val_mse: 0.2183 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/100
# 87/87 - 174s - loss: 1.0797 - accuracy: 0.3977 - mae: 0.4363 - mse: 0.2181 - precision: 0.3169 - recall: 0.0017 - f1_score: 0.0034 - val_loss: 1.0805 - val_accuracy: 0.3972 - val_mae: 0.4356 - val_mse: 0.2183 - val_precision: 0.4953 - val_recall: 0.0032 - val_f1_score: 0.0063
# Epoch 3/100
# 87/87 - 186s - loss: 1.0795 - accuracy: 0.3935 - mae: 0.4360 - mse: 0.2181 - precision: 0.4860 - recall: 0.0033 - f1_score: 0.0065 - val_loss: 1.0804 - val_accuracy: 0.4030 - val_mae: 0.4373 - val_mse: 0.2183 - val_precision: 0.4691 - val_recall: 0.0042 - val_f1_score: 0.0083
# Epoch 4/100
# 87/87 - 187s - loss: 1.0790 - accuracy: 0.4001 - mae: 0.4355 - mse: 0.2180 - precision: 0.5119 - recall: 0.0073 - f1_score: 0.0144 - val_loss: 1.0803 - val_accuracy: 0.4005 - val_mae: 0.4370 - val_mse: 0.2183 - val_precision: 0.5211 - val_recall: 0.0086 - val_f1_score: 0.0170
# Epoch 83/100
# 87/87 - 195s - loss: 1.0143 - accuracy: 0.4758 - mae: 0.4065 - mse: 0.2034 - precision: 0.5673 - recall: 0.1235 - f1_score: 0.2028 - val_loss: 1.1212 - val_accuracy: 0.3817 - val_mae: 0.4319 - val_mse: 0.2266 - val_precision: 0.5675 - val_recall: 0.1241 - val_f1_score: 0.2037
# Epoch 84/100
# 87/87 - 192s - loss: 1.0153 - accuracy: 0.4737 - mae: 0.4070 - mse: 0.2038 - precision: 0.5680 - recall: 0.1247 - f1_score: 0.2046 - val_loss: 1.1222 - val_accuracy: 0.3867 - val_mae: 0.4323 - val_mse: 0.2267 - val_precision: 0.5683 - val_recall: 0.1253 - val_f1_score: 0.2053
# Epoch 85/100
# 87/87 - 185s - loss: 1.0215 - accuracy: 0.4695 - mae: 0.4097 - mse: 0.2050 - precision: 0.5687 - recall: 0.1259 - f1_score: 0.2061 - val_loss: 1.1164 - val_accuracy: 0.3838 - val_mae: 0.4322 - val_mse: 0.2256 - val_precision: 0.5690 - val_recall: 0.1264 - val_f1_score: 0.2068
# Epoch 86/100
# 87/87 - 185s - loss: 1.0091 - accuracy: 0.4731 - mae: 0.4064 - mse: 0.2024 - precision: 0.5696 - recall: 0.1270 - f1_score: 0.2077 - val_loss: 1.1288 - val_accuracy: 0.3914 - val_mae: 0.4318 - val_mse: 0.2279 - val_precision: 0.5699 - val_recall: 0.1275 - val_f1_score: 0.2084
# Epoch 87/100
# 87/87 - 184s - loss: 1.0073 - accuracy: 0.4828 - mae: 0.4041 - mse: 0.2019 - precision: 0.5705 - recall: 0.1282 - f1_score: 0.2094 - val_loss: 1.1297 - val_accuracy: 0.3878 - val_mae: 0.4324 - val_mse: 0.2282 - val_precision: 0.5708 - val_recall: 0.1288 - val_f1_score: 0.2102
# Epoch 88/100
# 87/87 - 198s - loss: 1.0038 - accuracy: 0.4836 - mae: 0.4032 - mse: 0.2011 - precision: 0.5712 - recall: 0.1295 - f1_score: 0.2112 - val_loss: 1.1263 - val_accuracy: 0.3875 - val_mae: 0.4318 - val_mse: 0.2272 - val_precision: 0.5717 - val_recall: 0.1302 - val_f1_score: 0.2121
# Epoch 89/100
# 87/87 - 187s - loss: 1.0040 - accuracy: 0.4856 - mae: 0.4031 - mse: 0.2013 - precision: 0.5721 - recall: 0.1308 - f1_score: 0.2129 - val_loss: 1.1296 - val_accuracy: 0.3849 - val_mae: 0.4326 - val_mse: 0.2278 - val_precision: 0.5725 - val_recall: 0.1315 - val_f1_score: 0.2139
# Epoch 90/100
# 87/87 - 187s - loss: 1.0197 - accuracy: 0.4677 - mae: 0.4077 - mse: 0.2048 - precision: 0.5726 - recall: 0.1321 - f1_score: 0.2147 - val_loss: 1.1301 - val_accuracy: 0.3824 - val_mae: 0.4317 - val_mse: 0.2283 - val_precision: 0.5728 - val_recall: 0.1326 - val_f1_score: 0.2153
# Epoch 91/100
# 87/87 - 184s - loss: 1.0082 - accuracy: 0.4810 - mae: 0.4042 - mse: 0.2020 - precision: 0.5731 - recall: 0.1331 - f1_score: 0.2160 - val_loss: 1.1264 - val_accuracy: 0.3878 - val_mae: 0.4312 - val_mse: 0.2273 - val_precision: 0.5734 - val_recall: 0.1337 - val_f1_score: 0.2168
# Epoch 92/100
# 87/87 - 182s - loss: 1.0069 - accuracy: 0.4805 - mae: 0.4041 - mse: 0.2019 - precision: 0.5738 - recall: 0.1343 - f1_score: 0.2176 - val_loss: 1.1252 - val_accuracy: 0.3933 - val_mae: 0.4311 - val_mse: 0.2269 - val_precision: 0.5742 - val_recall: 0.1349 - val_f1_score: 0.2184
# Epoch 93/100
# 87/87 - 179s - loss: 1.0056 - accuracy: 0.4824 - mae: 0.4035 - mse: 0.2016 - precision: 0.5747 - recall: 0.1355 - f1_score: 0.2192 - val_loss: 1.1355 - val_accuracy: 0.3882 - val_mae: 0.4315 - val_mse: 0.2290 - val_precision: 0.5749 - val_recall: 0.1360 - val_f1_score: 0.2200
# Epoch 94/100
# 87/87 - 179s - loss: 1.0070 - accuracy: 0.4835 - mae: 0.4039 - mse: 0.2018 - precision: 0.5752 - recall: 0.1365 - f1_score: 0.2207 - val_loss: 1.1425 - val_accuracy: 0.3867 - val_mae: 0.4317 - val_mse: 0.2305 - val_precision: 0.5754 - val_recall: 0.1371 - val_f1_score: 0.2214
# Epoch 95/100
# 87/87 - 179s - loss: 0.9979 - accuracy: 0.4874 - mae: 0.4007 - mse: 0.2000 - precision: 0.5758 - recall: 0.1377 - f1_score: 0.2223 - val_loss: 1.1294 - val_accuracy: 0.3871 - val_mae: 0.4311 - val_mse: 0.2278 - val_precision: 0.5761 - val_recall: 0.1383 - val_f1_score: 0.2231
# Epoch 96/100
# 87/87 - 180s - loss: 0.9994 - accuracy: 0.4831 - mae: 0.4014 - mse: 0.2005 - precision: 0.5763 - recall: 0.1389 - f1_score: 0.2239 - val_loss: 1.1411 - val_accuracy: 0.3824 - val_mae: 0.4312 - val_mse: 0.2301 - val_precision: 0.5766 - val_recall: 0.1395 - val_f1_score: 0.2247
# Epoch 97/100
# 87/87 - 255s - loss: 0.9971 - accuracy: 0.4910 - mae: 0.4005 - mse: 0.1998 - precision: 0.5770 - recall: 0.1401 - f1_score: 0.2255 - val_loss: 1.1518 - val_accuracy: 0.3900 - val_mae: 0.4302 - val_mse: 0.2316 - val_precision: 0.5773 - val_recall: 0.1407 - val_f1_score: 0.2263
# Epoch 98/100
# 87/87 - 392s - loss: 0.9963 - accuracy: 0.4924 - mae: 0.3991 - mse: 0.1996 - precision: 0.5776 - recall: 0.1414 - f1_score: 0.2272 - val_loss: 1.1390 - val_accuracy: 0.3878 - val_mae: 0.4308 - val_mse: 0.2295 - val_precision: 0.5779 - val_recall: 0.1420 - val_f1_score: 0.2280
# Epoch 99/100
# 87/87 - 211s - loss: 0.9962 - accuracy: 0.4903 - mae: 0.3999 - mse: 0.1995 - precision: 0.5783 - recall: 0.1426 - f1_score: 0.2288 - val_loss: 1.1390 - val_accuracy: 0.3856 - val_mae: 0.4304 - val_mse: 0.2295 - val_precision: 0.5786 - val_recall: 0.1432 - val_f1_score: 0.2295
# Epoch 100/100
# 87/87 - 184s - loss: 0.9938 - accuracy: 0.4921 - mae: 0.3984 - mse: 0.1991 - precision: 0.5788 - recall: 0.1437 - f1_score: 0.2302 - val_loss: 1.1399 - val_accuracy: 0.3751 - val_mae: 0.4314 - val_mse: 0.2299 - val_precision: 0.5792 - val_recall: 0.1443 - val_f1_score: 0.2310

# %%
rounded_predictions = model_conv.predict_classes(X_valid, batch_size=128, verbose=0)
rounded_labels=np.argmax(Y_valid, axis=1)
print(classification_report(rounded_labels,rounded_predictions))
print(confusion_matrix(rounded_labels,rounded_predictions))
# Out:
# C:\Users\Sohail_Comp\AppData\Roaming\Python\Python37\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.40      0.59      0.47      1096
#            1       0.26      0.08      0.12       691
#            2       0.36      0.35      0.35       972
#
#     accuracy                           0.38      2759
#    macro avg       0.34      0.34      0.32      2759
# weighted avg       0.35      0.38      0.34      2759
#
# [[642  91 363]
#  [404  55 232]
#  [571  63 338]]

# %%
plt.figure(figsize=(8,6))
plt.rcParams.update({'font.size': 16})
plt.plot(pred.history['accuracy'])
plt.plot(pred.history['val_accuracy'])
plt.plot(pred.history['precision'])
plt.plot(pred.history['val_precision'])
plt.plot(pred.history['recall'])
plt.plot(pred.history['val_recall'])
plt.plot(pred.history['f1_score'])
plt.plot(pred.history['val_f1_score'])
plt.title('')
plt.ylabel('Score', fontsize=16)
plt.xlabel('Epoch', fontsize=16)

plt.legend(['accuracy', 'val_accuracy', 'precision', 'val_precision','recall', 'val_recall','f1_score', 'val_f1_score'], loc='down right',fontsize=14)
plt.tight_layout(pad=0)
plt.savefig('ZCRSLSTMscore.pdf', bbox_inches='tight')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Unrecognized location 'down right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   from ipykernel import kernelapp as app

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import sklearn
plt.figure(figsize=(20,50),dpi=300)
y, sr = librosa.load("C:\\Users\\Sohail_Comp\\Downloads\\archive (9)\\Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00.wav")


fig, ax = plt.subplots(nrows=3, sharex=True)
librosa.display.waveshow(y, sr=sr, ax=ax[0])
ax[0].set(title='Envelope view, mono')
ax[0].label_outer()


librosa.display.waveshow(y, sr=sr, ax=ax[1])
ax[1].set(title='Envelope view, stereo')
ax[1].label_outer()

y_harm, y_perc = librosa.effects.hpss(y)
librosa.display.waveshow(y_harm, sr=sr, alpha=0.5, ax=ax[2], label='Harmonic')
librosa.display.waveshow(y_perc, sr=sr, color='r', alpha=0.5, ax=ax[2], label='Percussive')
ax[2].set(title='Multiple waveforms')
ax[2].legend()


fig, (ax, ax2) = plt.subplots(nrows=2, sharex=True)
ax.set(xlim=[6.0, 6.01], title='Sample view', ylim=[-0.2, 0.2])
librosa.display.waveshow(y, sr=sr, ax=ax, marker='.', label='Full signal')
librosa.display.waveshow(y_harm, sr=sr, alpha=0.5, ax=ax2, label='Harmonic')
librosa.display.waveshow(y_perc, sr=sr, color='r', alpha=0.5, ax=ax2, label='Percussive')
ax.label_outer()
ax.legend()
ax2.legend()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import sklearn


y, sr = librosa.load("C:\\Users\\Sohail_Comp\\Downloads\\archive (9)\\CF003 - Active - Day - (215).wav")

fig, ax = plt.subplots(nrows=3, sharex=True)
librosa.display.waveshow(y, sr=sr, ax=ax[0])
ax[0].set(title='Envelope view, mono')
ax[0].label_outer()


librosa.display.waveshow(y, sr=sr, ax=ax[1])
ax[1].set(title='Envelope view, stereo')
ax[1].label_outer()

y_harm, y_perc = librosa.effects.hpss(y)
librosa.display.waveshow(y_harm, sr=sr, alpha=0.5, ax=ax[2], label='Harmonic')
librosa.display.waveshow(y_perc, sr=sr, color='r', alpha=0.5, ax=ax[2], label='Percussive')
ax[2].set(title='Multiple waveforms')
ax[2].legend()


fig, (ax, ax2) = plt.subplots(nrows=2, sharex=True)
ax.set(xlim=[6.0, 6.01], title='Sample view', ylim=[-0.2, 0.2])
librosa.display.waveshow(y, sr=sr, ax=ax, marker='.', label='Full signal')
librosa.display.waveshow(y_harm, sr=sr, alpha=0.5, ax=ax2, label='Harmonic')
librosa.display.waveshow(y_perc, sr=sr, color='r', alpha=0.5, ax=ax2, label='Percussive')
ax.label_outer()
ax.legend()
ax2.legend()

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Oh, no! There are no automatic insights available for the file types used in this dataset. As your Kaggle kerneler bot, I'll keep working to fine-tune my hyper-parameters. In the meantime, please feel free to try a different dataset.

# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Fork Notebook" button at the top of this kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!

# %%
# t-test
from math import sqrt
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from scipy.stats import t

# function for calculating the t-test for two dependent samples
def dependent_ttest(data1, data2, alpha):
	# calculate means
	mean1, mean2 = mean(data1), mean(data2)
	# number of paired samples
	n = len(data1)
	# sum squared difference between observations
	d1 = sum([(data1[i]-data2[i])**2 for i in range(n)])
	# sum difference between observations
	d2 = sum([data1[i]-data2[i] for i in range(n)])
	# standard deviation of the difference between means
	sd = sqrt((d1 - (d2**2 / n)) / (n - 1))
	# standard error of the difference between the means
	sed = sd / sqrt(n)
	# calculate the t statistic
	t_stat = (mean1 - mean2) / sed
	# degrees of freedom
	df = n - 1
	# calculate the critical value
	cv = t.ppf(1.0 - alpha, df)
	# calculate the p-value
	p = (1.0 - t.cdf(abs(t_stat), df)) * 2.0
	# return everything
	return t_stat, df, cv, p

# seed the random number generator
seed(1)


MFCCH = [0.83,0.81,0.79,0.79,
0.71,0.66,0.67,0.66,
0.73,0.69,0.69,0.68,
0.82,0.81,0.78,0.77
]
svd = [0.77,0.75,0.73,0.72,
0.68,0.65,0.64,0.64,
0.69,0.67,0.65,0.64,
0.81,0.81,0.77,0.77
]
chi = [0.83,0.82,0.80,0.80,
0.67,0.64,0.64,0.64,
0.72,0.69,0.69,0.68,
0.83,0.82,0.80,0.79
]

pca = [0.82,0.81,0.79,0.79,
0.70,0.66,0.66,0.66,
0.73,0.69,0.68,0.68,
0.82,0.81,0.77,0.77

]

simple =[0.83,0.81,0.79,0.79,
0.70,0.67,0.67,0.66,
0.71,0.68,0.68,0.67,
0.82,0.82,0.77,0.77


]



# calculate the t test
alpha =0.5
t_stat, df, cv, p = dependent_ttest(MFCCH, svd, alpha)
print('t=%.3f, df=%d' % (t_stat, df))
print(cv)
# interpret via critical value
if abs(t_stat) <= cv:
	print('Accept null hypothesis that the means are equal.')
else:
	print('Reject the null hypothesis that the means are not equal.')
# Out:
# t=5.490, df=15
# 6.749466851396602e-17
# Reject the null hypothesis that the means are not equal.
